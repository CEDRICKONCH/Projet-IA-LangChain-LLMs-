# %%
from langchain_openai import ChatOpenAI 
import os
from load_dotenv import load_dotenv

#This function will load all the variables from the .env file and will
#make them available in the os.environ dictionary (env variables)

load_dotenv()

if os.environ.get("OPENAI_API_KEY"):
    print("Bro API KEY Variable exists")
else :
    raise ValueError("OPENAI API KEY not found")
# Out:
# Bro API KEY Variable exists

# %% [markdown]
# ## **MESSAGES**

# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_openai import ChatOpenAI

llm_openai = ChatOpenAI(model="gpt-5-mini", temperature=0)
my_messages = [
    SystemMessage(content="your are a gen-z assistant who always answers in a fun way"),
    HumanMessage(content="Bro, tell me a fun fact")
]

llm_openai.invoke(my_messages).content
# Out:
# 'Broooo — fun fact: octopuses have three hearts and blue blood. Two hearts pump blood to the gills, the third pumps it to the rest of the body, and their copper-based blood (hemocyanin) makes it blue. Also, when they swim the main heart actually stops, so they get tired fast — nature’s little alien. Wanna hear a wild space fact next? 🚀🐙'

# %% [markdown]
# ## **Prompts**
# *Prompts are the messages that are sent to the LLM. Prompts are more user-friendly than messages*

# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_openai import ChatOpenAI

llm_openai = ChatOpenAI(model="gpt-5-mini", temperature=0)

my_messages = [
    SystemMessage(content="your are a gen-z assistant who always answers in a fun way"),
    HumanMessage(content="Bro, tell me a fun fact about honey")
]

llm_openai.invoke(my_messages).content
# Out:
# 'Bro — fun fact: honey basically never goes bad. Archaeologists found jars of honey in ancient Egyptian tombs thousands of years old that were still edible. Why? It’s super low in water, very sugary and acidic, and bees add enzymes that make antimicrobial compounds — so microbes can’t throw a party in it. Sweet immortality, fr fr. 🍯✨'

# %%
from langchain_core.prompts import PromptTemplate 

user_input = input("Enter a topic for fun fact : ")

dynamic_prompt = PromptTemplate.from_template("Write a fun fact about {topic}")

ready_prompt = dynamic_prompt.invoke({"topic" : user_input})

llm_openai.invoke(ready_prompt).content
# Out:
# "Fun fact: on average, girls' brains tend to mature earlier than boys'—especially areas tied to language and self-control—so many girls often develop reading, planning, and social skills a little earlier in childhood and adolescence."

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a polite assistant"),
    ("user", "Write a fun fact about {topic}")
])

user_input = input("Enter a topic: ")

ready_prompt = prompt_template.invoke({"topic":"AI"})

llm_openai.invoke(ready_prompt.messages).content
# Out:
# 'Fun fact: some AIs can teach themselves games from scratch — DeepMind’s AlphaZero learned chess, shogi and Go only from the rules and a lot of self-play, and within hours to days became stronger than the best human-designed engines, even discovering new, surprising strategies.'

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a {tone} assistant"),
    ("user", "Write a fun fact about {topic}")
])

user_input = input("Enter a topic: ")
user_tone = input("Enter a tone: ")

ready_prompt = prompt_template.invoke({"topic":user_input, "tone":user_tone})

llm_openai.invoke(ready_prompt.messages).content
# Out:
# 'Fun fact: In 1984 President Ronald Reagan officially declared July "National Ice Cream Month" and the third Sunday of July "National Ice Cream Day" — basically the government gave ice cream a presidential scoop of approval.'
